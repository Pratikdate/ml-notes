# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratikdate/ML-Models/blob/main/Regressior_and_classifier_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import io
from sklearn.datasets import load_boston

from sklearn.ensemble import RandomForestRegressor
# %matplotlib inline
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split 
from sklearn import linear_model,metrics
from sklearn.metrics import mean_squared_error

# %%
boston=load_boston()
df=pd.DataFrame(boston.data)
df.columns=boston.feature_names
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
# ...

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
#x=df.drop('INDUS',axis=1)
#y=df.INDUS
x=df[['AGE']]
y=df[['TAX']]
x_train=x[:400]
y_train=y[:400]
x_test=x[400:]
y_test=y[400:]

# %%
model=linear_model.LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#x=df.drop('INDUS',axis=1)
#y=df.INDUS
model.score(x_test, y_test, )
#model.apply(x_test)
# Out:
# -4.7024768673042665

# %%
predictions=model.predict(x_test)#.loc[:]#,['AGE']])

# %%
lin_mse = mean_squared_error(y_test, predictions)
lin_rmse = np.sqrt(lin_mse)
lin_rmse
# Out:
# 258.3752385667741

# %%
plt.scatter(x_train,y_train,alpha=0.5  )
plt.scatter(x_test.loc[:],predictions)
plt.plot()
# Out:
# []

# %%
df.hist(bins=40,figsize=(20,20) )
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc44fab7390>,
# ...
#       dtype=object)

# %%
df.plot(kind='scatter',x='TAX',y='RM',alpha=0.6)

# %%
df.plot(kind='scatter',x='CRIM',y='AGE',alpha=0.2,colorbar='True',figsize=(10,10))

# %%
from pandas.plotting import scatter_matrix
attributes = ['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO']
scatter_matrix(df[attributes], figsize=(20, 20),alpha=0.9)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc44e8e4790>,
# ...
#       dtype=object)

# %%
lin_mse = mean_squared_error(y, predictions)
lin_rmse = np.sqrt(lin_mse)
lin_rmse
# Out:
# 267.9632673033738

# %% [markdown]
# DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor
tree_reg = DecisionTreeRegressor()
tree_reg.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
predictions=tree_reg.predict(x_test[:])
print(y_test[:])
print('_ _ _ _ _')
# Out:
#        TAX
# 400  666.0
# 401  666.0
# 402  666.0
# 403  666.0
# 404  666.0
# ..     ...
# 501  273.0
# 502  273.0
# 503  273.0
# 504  273.0
# 505  273.0
#
# [106 rows x 1 columns]
# _ _ _ _ _

# %%
tree_mse = mean_squared_error(y_test[:], predictions)
tree_rmse = np.sqrt(tree_mse)
print('standard deviation  ',tree_rmse.std())
tree_rmse
# Out:
# standard deviation   0.0
# 213.78524114049037

# %%
from sklearn.model_selection import cross_val_score



scores = cross_val_score(tree_reg,x_test , y_test,
 scoring="neg_mean_squared_error", cv=10)
tree_rmse_scores = np.sqrt(-scores)
tree_rmse_scores
# Out:
# array([ 13.56801051, 167.57576306, 117.260394  ,   0.        ,
#         30.33899381, 187.9489776 , 157.79108023, 195.27519044,
#        176.8120471 , 339.17104829])

# %%
plt.scatter(x_train,y_train)
plt.scatter(x_test,predictions)

# %% [markdown]
# RandomForestRegression

# %%
from sklearn.ensemble import RandomForestRegressor



forest_reg = RandomForestRegressor()
forest_reg.fit(x_train, y_train)
predictions=forest_reg.predict(x_test[:])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   import sys

# %%
tree_mse = mean_squared_error(y_test[:], predictions)
tree_rmse = np.sqrt(tree_mse)

print('standard deviation  ',tree_rmse.std())
tree_rmse
# Out:
# standard deviation   0.0
# 260.4908885257524

# %%
from sklearn.model_selection import GridSearchCV



param_grid = [
 {'n_estimators': [3, 1, 3], 'max_features': [2, 4, 6, 8]},
 {'bootstrap': [False], 'n_estimators': [3, 10], 'max_features': [2, 3, 4]},
 ]
forest_reg = RandomForestRegressor()
grid_search = GridSearchCV(forest_reg, param_grid, cv=5,
 scoring='neg_mean_squared_error',
return_train_score=True)
grid_search.fit(x_train,y_train)


grid_search.predict(x_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
from sklearn.model_selection import cross_val_score



scores = cross_val_score(forest_reg,x_test , y_test,
 scoring="neg_mean_squared_error", cv=10)
tree_rmse_scores = np.sqrt(-scores)
tree_rmse_scores
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
plt.scatter(x_train,y_train)
plt.scatter(x_test,predictions)

# %% [markdown]
# SVR support vector regressor

# %%
from sklearn.svm import SVR
svr_reg = SVR()
svr_reg.fit(x_train, y_train)
predictions=svr_reg.predict(x_test[:])
predictions
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([350.56632538, 350.56632538, 350.56632538, 347.43566928,
#        330.8656586 , 350.56632538, 350.56632538, 350.56632538,
#        349.1740428 , 350.56632538, 350.56632538, 350.56632538,
#        350.56632538, 350.56632538, 350.56632538, 350.56632538,
#        340.55199432, 337.72504618, 350.56632538, 312.90996953,
#        350.56632538, 346.68420845, 335.0453034 , 330.27740705,
#        302.28597492, 346.79513013, 289.86878816, 317.29712549,
#        316.0867295 , 347.01341969, 332.22283499, 345.51089833,
#        309.64530111, 335.59365263, 346.34438739, 345.87499697,
#        344.22450192, 350.56632538, 335.59365263, 345.00961721,
#        342.97462328, 348.58566911, 350.56632538, 350.56632538,
# ...

# %%
svr_mse = mean_squared_error(y_test[:], predictions)
svr_rmse = np.sqrt(svr_mse)

print('standard deviation  ',svr_rmse.std())
svr_rmse
# Out:
# standard deviation   0.0
# 314.57267533039027

# %%
plt.scatter(x_train,y_train)
plt.scatter(x_test,predictions)

# %% [markdown]
# Classification

# %%
import tensorflow as tf
from sklearn.datasets import fetch_openml
mnist = fetch_openml('mnist_784', version=1)
mnist.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'categories', 'feature_names', 'target_names', 'DESCR', 'details', 'url'])

# %%
import matplotlib.pyplot as plt

X, y = mnist["data"], mnist["target"]
X.shape
# Out:
# (70000, 784)

# %%
k=np.matrix(X)
a=k[[6]].reshape(28,28)

print(np.linalg.svd(a)[1])
plt.imshow(a[:27].getI())
#plt.imshow()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a8b4d89e8e57> in <module>()
# ----> 1 k=np.matrix(X)
#       2 a=k[[6]].reshape(28,28)
#       3
#       4 print(np.linalg.svd(a)[1])
#       5 plt.imshow(a[:27].getI())
#
# NameError: name 'np' is not defined

# %%
from sklearn.tree import DecisionTreeClassifier

mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0

number=3
plt.imshow(x_train[number])
print('Given Number is ',y_train[number])
# Out:
# ...
# 11501568/11490434 [==============================] - 0s 0us/step
# Given Number is  1

# %%
nsamples, nx, ny = x_train.shape
d2_train_dataset = x_train.reshape((nsamples,nx*ny))

d2_train_dataset.shape
# Out:
# (60000, 784)

# %%
nsamples, nx, ny = x_test.shape
d2_test_dataset = x_test.reshape((nsamples,nx*ny))

d2_test_dataset.shape
# Out:
# (10000, 784)

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# %%
from IPython.display import Image
try:
  filename = take_photo()
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))

# %%
from PIL import Image
from urllib import request
from io import BytesIO
from matplotlib import pyplot as plt 
import numpy as np
url = "https://source.unsplash.com/1600x900/?ship"
res = request.urlopen(url).read()
Sample_Image = Image.open(filename).resize((28,28))

array=np.asarray(Sample_Image)
#string=np.array2string(array)
print()
#print(string)
print(Sample_Image.size)

IMAGE_CHANNEL = 2
import cv2
def prepare(img_array,filepath):
    IMG_SIZE = 28
    img_array = cv2.imread(filepath, cv2.COLOR_BGR2YCrCb  )
    new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
    return new_array.reshape(3,784)#, IMAGE_CHANNEL)
plt.imshow(array)
array=prepare(array,filename)
array.shape
# Out:
# (28, 28)
# (3, 784)

# %%
img=tf.keras.preprocessing.image.load_img(
    filename, grayscale=False, color_mode="rgb", target_size=None, interpolation="nearest"
)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=480x640 at 0x7FAB34573950>

# %%
#image = tf.keras.preprocessing.image.load_img(filename)
input_arr = tf.keras.preprocessing.image.img_to_array(img)
input_arr = np.array([input_arr])  # Convert single image to a batch.
#predictions = model.predict(input_arr)
array=prepare(input_arr,filename)
array=255-array
# Out:
# array([ 60,  57,  52,  54,  52,  43,  53,  52,  43,  52,  49,  44,  50,
#         47,  41,  46,  46,  40,  45,  45,  38,  44,  43,  37,  42,  42,
#         36,  42,  42,  36,  42,  42,  36,  38,  38,  32,  37,  37,  31,
#         37,  37,  31,  36,  36,  30,  36,  35,  31,  35,  35,  29,  35,
#         32,  27,  33,  31,  24,  33,  30,  25,  33,  30,  26,  33,  29,
#         25,  34,  31,  27,  30,  29,  25,  29,  29,  23,  28,  28,  22,
#         27,  28,  21,  27,  25,  24,  58,  55,  47,  55,  52,  44,  53,
#         50,  42,  50,  48,  38,  47,  46,  36,  48,  46,  38,  47,  45,
#         37,  45,  43,  35,  45,  43,  33,  45,  42,  34,  47,  49,  39,
#         62,  64,  52,  95,  98,  85, 141, 145, 133, 129, 132, 122,  70,
#         74,  63,  50,  48,  40,  36,  37,  28,  35,  34,  26,  36,  32,
#         27,  34,  32,  22,  33,  31,  23,  32,  30,  22,  33,  31,  23,
#         32,  30,  22,  31,  29,  21,  31,  29,  21,  29,  29,  25,  58,
# ...

# %%
for i in array:
    if i <0:
        i=0
        continue
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-53120d9b6a00> in <module>()
#       1 for i in array:
# ----> 2     if i <0:
#       3         i=0
#       4         continue
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
from sklearn.linear_model import SGDClassifier
sgd_clf = SGDClassifier(random_state=42)
#sgd_clf = DecisionTreeClassifier()
sgd_clf.fit(d2_train_dataset, y_train)
# Out:
# SGDClassifier(random_state=42)

# %%
predictions=sgd_clf.predict((array/225))
predictions
# Out:
# array([2, 2, 7], dtype=uint8)

# %%
tree_mse = mean_squared_error(y_test, predictions)
tree_rmse = np.sqrt(tree_mse)

print('standard deviation  ',)#sgd_clf.std())
tree_rmse
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-68366919b2a3> in <module>()
# ----> 1 tree_mse = mean_squared_error(y_test, predictions)
#       2 tree_rmse = np.sqrt(tree_mse)
#       3
#       4 print('standard deviation  ',)#sgd_clf.std())
#       5 tree_rmse
#
# NameError: name 'mean_squared_error' is not defined

# %%
from sklearn.model_selection import cross_val_score



cross_val_score(sgd_clf, d2_test_dataset, y_test, cv=3, scoring="accuracy")

# %%
k=47


pr=sgd_clf.predict(d2_test_dataset[[k]])

print('prediction is ', pr)
print(y_test[[k]])


a=d2_test_dataset[[k]].reshape(28,28)
plt.imshow(a)

# %% [markdown]
# SVC support vector classifier

# %%
from sklearn.svm import SVC

# %%
svc_clss = SVC()
svc_clss.fit(d2_train_dataset, y_train)
pr=svc_clss.predict(array)#d2_test_dataset)
pr
# Out:
# array([5, 5, 5], dtype=uint8)

# %%
from sklearn.model_selection import cross_val_score



cross_val_score(svc_clss, d2_test_dataset, y_test, cv=3, scoring="accuracy")
# Out:
# array([0.93491302, 0.95229523, 0.96669667])

# %%
m=19


pr=svc_clss_clf.predict(d2_test_dataset[[m]])

print('prediction is ', pr)
print(y_test[[m]])

a=d2_test_dataset[[m]].reshape(28,28)
plt.imshow(a)
# Out:
# prediction is  [4]
# [4]

# %% [markdown]
# MLPClassifier

# %%
from sklearn.neural_network import MLPClassifier

mlp_clss = MLPClassifier()
mlp_clss.fit(d2_train_dataset, y_train)
pr=mlp_clss.predict(d2_test_dataset)
predictions
# Out:
# array([7, 2, 1, ..., 4, 5, 6], dtype=uint8)

# %%
from sklearn.model_selection import cross_val_score



cross_val_score(mlp_clss, d2_test_dataset, y_test, cv=3, scoring="accuracy")
# Out:
# array([0.92531494, 0.94239424, 0.94929493])

# %%
m=19


pr=mlp_clss.predict(d2_test_dataset[[m]])

print('prediction is ', pr)
print(y_test[[m]])

a=d2_test_dataset[[m]].reshape(28,28)
plt.imshow(a)
# Out:
# prediction is  [4]
# [4]

# %% [markdown]
# KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier

kn_clss = MLPClassifier()
kn_clss.fit(d2_train_dataset, y_train)
pr=kn_clss.predict(d2_test_dataset)
pr
# Out:
# array([7, 2, 1, ..., 4, 5, 6], dtype=uint8)

# %%
from sklearn.model_selection import cross_val_score



cross_val_score(kn_clss, d2_test_dataset, y_test, cv=3, scoring="accuracy")
# Out:
# array([0.92591482, 0.9429943 , 0.95109511])

# %%
m=14


pr=kn_clss.predict(d2_test_dataset[[m]])

print('prediction is ', pr)
print(y_test[[m]])

a=d2_test_dataset[[m]].reshape(28,28)
plt.imshow(a)
# Out:
# prediction is  [1]
# [1]

# %% [markdown]
# GaussianProessClassifier

# %%
from sklearn.gaussian_process import GaussianProcessClassifier
gu_clss = MLPClassifier()
gu_clss.fit(d2_train_dataset, y_train)
pr=gu_clss.predict(d2_test_dataset)
pr
# Out:
# array([7, 2, 1, ..., 4, 5, 6], dtype=uint8)

# %%
from sklearn.model_selection import cross_val_score



cross_val_score(kn_clss, d2_test_dataset, y_test, cv=3, scoring="accuracy")
# Out:
# array([0.92111578, 0.94029403, 0.94779478])

# %%
m=19


pr=kn_clss.predict(d2_test_dataset[[m]])

print('prediction is ', pr)
print(y_test[[m]])

a=d2_test_dataset[[m]].reshape(28,28)
plt.imshow(a)
# Out:
# prediction is  [4]
# [4]

# %%
RBF

# %% [markdown]
# RBF

# %%
x=6+6
print(x)
x+4
# Out:
# 12
# 16

# %%
from sklearn.datasets import load_iris
from sklearn import tree
iris= load_iris()
X, y = iris.data, iris.target
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, y)
tree.plot_tree(clf)

# %%
tree.plot_tree(clf)
dir()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-de2aa0d2de2e> in <module>()
# ----> 1 tree.plot_tree(clf)
#       2 dir()
#
# NameError: name 'tree' is not defined

# %%
from sklearn.model_selection import cross_val_score
from sklearn.datasets import load_iris
from sklearn.ensemble import AdaBoostClassifier

X, y = load_iris(return_X_y=True)
clf = AdaBoostClassifier(n_estimators=1000,learning_rate=0.001)
scores = cross_val_score(clf, X, y, cv=5)
scores.mean()
#scores
# Out:
# 0.9399999999999998

# %%
# Out:
# ['In',
#  'Out',
#  '_',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  '_sh',
#  'exit',
#  'get_ipython',
#  'quit']
